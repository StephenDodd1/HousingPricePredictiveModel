# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import scipy 
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale

from library.sb_utils import save_file

# %% [markdown]
# ### Read df from cleaned csv

# %%
df = pd.read_csv('../data/house_data_cleaned.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning Street Alley Neighborhood Condition1 Condition2  \
# 0   1          60       RL   Pave  None      CollgCr       Norm       Norm
# 1   2          20       RL   Pave  None      Veenker      Feedr       Norm
# 2   3          60       RL   Pave  None      CollgCr       Norm       Norm
# 3   4          70       RL   Pave  None      Crawfor       Norm       Norm
# 4   5          60       RL   Pave  None      NoRidge       Norm       Norm
#
#   HouseStyle  OverallQual  ... TotalBsmtSF  Heating GrLivArea KitchenQual  \
# 0     2Story            7  ...         856     GasA      1710          Gd
# 1     1Story            6  ...        1262     GasA      1262          TA
# 2     2Story            7  ...         920     GasA      1786          Gd
# 3     2Story            7  ...         756     GasA      1717          Gd
# 4     2Story            8  ...        1145     GasA      2198          Gd
#
#    GarageType GarageFinish  GarageCars SalePrice TotalSF HasPool
# 0      Attchd          RFn           2    208500    2566   False
# 1      Attchd          RFn           2    181500    2524   False
# 2      Attchd          RFn           2    223500    2706   False
# 3      Detchd          Unf           3    140000    2473   False
# 4      Attchd          RFn           3    250000    3343   False
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Figure 1 - Correlation of SalePrice to TotalsSF

# %%
model = sm.OLS(df['SalePrice'], sm.add_constant(df['TotalSF']))
p = model.fit().params
# generate x-values for your regression line (two is sufficient)
x = df['TotalSF']
# scatter-plot data
ax = df.plot(x='TotalSF', y='SalePrice', kind='scatter', alpha = 0.1, c='r')
# plot regression line on the same axes, set x-axis limits
ax.plot(x, p.const + p['TotalSF'] * x)
print ("correlation :",scipy.stats.pearsonr(df['SalePrice'], df['TotalSF']))
# Out:
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# correlation : (0.7822600527979842, 5.511173086257728e-302)

# %% [markdown]
# ### Figure 2.1 - Correlation of SalePrice to TotalsSF w/ pools

# %%
pool_model = sm.OLS(df[df['HasPool'] == True]['SalePrice'], sm.add_constant(df[df['HasPool'] == True]['TotalSF']))
pool_p = pool_model.fit().params
# generate x-values for your regression line (two is sufficient)
x = df[df['HasPool'] == True]['TotalSF']
# scatter-plot data
ax = df[df['HasPool'] == True].plot(x='TotalSF', y='SalePrice', kind='scatter', alpha = 0.1)
# plot regression line on the same axes, set x-axis limits
ax.plot(x, pool_p.const + pool_p['TotalSF'] * x)
print ("correlation :",scipy.stats.pearsonr(df[df['HasPool'] == True]['SalePrice'], df[df['HasPool'] == True]['TotalSF']))
# Out:
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# correlation : (0.16802605710441615, 0.7187596908749201)

# %% [markdown]
# ### Figure 2.2 - Correlation of SalePrice to TotalsSF w/o pools

# %%
no_pool_model = sm.OLS(df[df['HasPool'] == False]['SalePrice'], sm.add_constant(df[df['HasPool'] == False]['TotalSF']))
no_pool_p = no_pool_model.fit().params
# generate x-values for your regression line (two is sufficient)
x = df[df['HasPool'] == False]['TotalSF']
# scatter-plot data
ax = df[df['HasPool'] == False].plot(x='TotalSF', y='SalePrice', kind='scatter', alpha = 0.1, c='r')
# plot regression line on the same axes, set x-axis limits
ax.plot(x, no_pool_p.const + no_pool_p['TotalSF'] * x)
print ("correlation :",scipy.stats.pearsonr(df[df['HasPool'] == False]['SalePrice'], df[df['HasPool'] == False]['TotalSF']))
# Out:
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# correlation : (0.8166448166913953, 0.0)

# %% [markdown]
# ### Figure 2.3 - Correlation of SalePrice to TotalsSF w/ pools after correcting outlier at index 1298

# %%
# One thing that stands out is how greatly the outliers affect the dataset that has a pool. So I will 
# re-run the regression, excluding those data points.
print('Before update : \033[1;48;34m' + str(df.iloc[1298]['SalePrice'])) 
# I have come to the conclusion that this outlier must be missing a zero on price. I say this because the
# indicators I have found to have strong correlations with price, for instance Area is very high, and the 
# Quality measures such as kitchen quality and Overall Style, are maximum values. The only value that
# doesn't fit the data is the sale price. So I will update it to $1.6 million.
df.at[1298,'SalePrice'] = 1600000
print('\033[mAfter update : \033[1;48;34m' + str(df.iloc[1298]['SalePrice']))
# Now to run it again.
pool_model = sm.OLS(df[df['HasPool'] == True]['SalePrice'], 
    sm.add_constant(df[df['HasPool'] == True]['TotalSF']))
pool_p = pool_model.fit().params
# generate x-values for your regression line (two is sufficient)
x = df[df['HasPool'] == True]['TotalSF']
# scatter-plot data
ax = df[df['HasPool'] == True].plot(x='TotalSF', y='SalePrice', kind='scatter', alpha = 0.5)
# plot regression line on the same axes, set x-axis limits
line1, = ax.plot(x, no_pool_p.const + no_pool_p['TotalSF'] * x, c='purple')
line2, = ax.plot(x, pool_p.const + pool_p['TotalSF'] * x)
ax.legend([line1, line2],['No pool','Pool'])
plt.show()
print ("\033[mcorrelation w/ pools :\033[1;48;34m",scipy.stats.pearsonr(df[df['HasPool'] == True]['SalePrice'], \
    df[df['HasPool'] == True]['TotalSF']))
# Out:
# Before update : 160000
# After update : 1600000
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# correlation w/ pools : (0.9809888892055241, 9.474037124304883e-05)

# %% [markdown]
# ### Figure 2.4 - Correlation of SalePrice to TotalsSF w/o pools after correcting outlier at index 1298

# %%
no_pool_model = sm.OLS(df[df['HasPool'] == False]['SalePrice'], sm.add_constant(df[df['HasPool'] == False]['TotalSF']))
no_pool_p = no_pool_model.fit().params
x = df[df['HasPool'] == False]['TotalSF']
ax = df[df['HasPool'] == False].plot(x='TotalSF', y='SalePrice', kind='scatter', alpha = 0.1)
line1, = ax.plot(x, no_pool_p.const + no_pool_p['TotalSF'] * x, c='orange')
line2, = ax.plot(x, pool_p.const + pool_p['TotalSF'] * x, c='r')
ax.legend([line1, line2],['No pool','Pool'])
plt.show()
print ("correlation with pool:",scipy.stats.pearsonr(df[df['HasPool'] == True]['SalePrice'], df[df['HasPool'] == True]['TotalSF']))
print ("correlation without pool:",scipy.stats.pearsonr(df[df['HasPool'] == False]['SalePrice'], df[df['HasPool'] == False]['TotalSF']))
# Out:
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# correlation with pool: (0.9809888892055241, 9.474037124304883e-05)
# correlation without pool: (0.8166448166913953, 0.0)

# %% [markdown]
# ### Explore neighborhood statistics, particularly how Edwards neighborhoods compares to the others.
# ###### Note that the correlation for homes with pools more closely matches after increasing the sale price of our outlier by a factor of 10.

# %%
nb_mean_dict = {}
print('Mean\n')
for nb in df['Neighborhood']:    
    nb_mean_dict[nb]= df[df['Neighborhood'] == nb]['SalePrice'].mean()
for idx, x in enumerate(sorted(nb_mean_dict.items(), key=lambda item: -item[1])):
    print(str(idx + 1) + '. ' + str(x[0]) +' - $ ' + '{:,.0f}'.format(x[1]) if \
          x[0] != 'Edwards' else str(idx + 1) + '. ' + '\033[1;48;34m' + str(x[0]) + \
          ' - $ ' + '{:,.0f}'.format(x[1]) + '\033[m')
print('\nMedian\n')
nb_median_dict = {}
for nb in df['Neighborhood']:    
    nb_median_dict[nb]= df[df['Neighborhood'] == nb]['SalePrice'].median()

for idx, x in enumerate(sorted(nb_median_dict.items(), key=lambda item: -item[1])):
    print(str(idx + 1) + '. ' + str(x[0]) +' - $ ' + '{:,.0f}'.format(x[1]) if \
          x[0] != 'Edwards' else str(idx + 1) + '. ' + '\033[1;48;34m' + str(x[0]) + \
          ' - $ ' + '{:,.0f}'.format(x[1]) + '\033[m')
print('\nMinimum\n')
nb_min_dict = {}
for nb in df['Neighborhood']:    
    nb_min_dict[nb]= df[df['Neighborhood'] == nb]['SalePrice'].min()
for idx, x in enumerate(sorted(nb_min_dict.items(), key=lambda item: -item[1])):
    print(str(idx + 1) + '. ' + str(x[0]) +' - $ ' + '{:,.0f}'.format(x[1]) if \
          x[0] != 'Edwards' else str(idx + 1) + '. ' + '\033[1;48;34m' + str(x[0]) + \
          ' - $ ' + '{:,.0f}'.format(x[1]) + '\033[m')
print('\nMaximum\n')
nb_max_dict = {}
for nb in df['Neighborhood']:    
    nb_max_dict[nb]= df[df['Neighborhood'] == nb]['SalePrice'].max()

for idx, x in enumerate(sorted(nb_max_dict.items(), key=lambda item: -item[1])):
    print(str(idx + 1) + '. ' + str(x[0]) +' - $ ' + '{:,.0f}'.format(x[1]) if \
          x[0] != 'Edwards' else str(idx + 1) + '. ' + '\033[1;48;34m' + str(x[0]) + \
          ' - $ ' + '{:,.0f}'.format(x[1]) + '\033[m')
# Out:
# Mean
#
# 1. NoRidge - $ 335,295
# 2. NridgHt - $ 316,271
# 3. StoneBr - $ 310,499
# 4. Timber - $ 242,247
# 5. Veenker - $ 238,773
# 6. Somerst - $ 225,380
# 7. ClearCr - $ 212,565
# 8. Crawfor - $ 210,625
# 9. CollgCr - $ 197,966
# 10. Blmngtn - $ 194,871
# 11. Gilbert - $ 192,855
# 12. NWAmes - $ 189,050
# 13. SawyerW - $ 186,556
# 14. Mitchel - $ 156,270
# 15. NAmes - $ 145,847
# 16. NPkVill - $ 142,694
# 17. Edwards - $ 142,620
# 18. SWISU - $ 142,591
# 19. Blueste - $ 137,500
# 20. Sawyer - $ 136,793
# 21. OldTown - $ 128,225
# 22. BrkSide - $ 124,834
# 23. BrDale - $ 104,494
# 24. IDOTRR - $ 100,124
# 25. MeadowV - $ 98,576
#
# Median
#
# 1. NridgHt - $ 315,000
# 2. NoRidge - $ 301,500
# 3. StoneBr - $ 278,000
# 4. Timber - $ 228,475
# 5. Somerst - $ 225,500
# 6. Veenker - $ 218,000
# 7. Crawfor - $ 200,624
# 8. ClearCr - $ 200,250
# 9. CollgCr - $ 197,200
# 10. Blmngtn - $ 191,000
# 11. NWAmes - $ 182,900
# 12. Gilbert - $ 181,000
# 13. SawyerW - $ 179,900
# 14. Mitchel - $ 153,500
# 15. NPkVill - $ 146,000
# 16. NAmes - $ 140,000
# 17. SWISU - $ 139,500
# 18. Blueste - $ 137,500
# 19. Sawyer - $ 135,000
# 20. BrkSide - $ 124,300
# 21. Edwards - $ 121,750
# 22. OldTown - $ 119,000
# 23. BrDale - $ 106,000
# 24. IDOTRR - $ 103,000
# 25. MeadowV - $ 88,000
#
# Minimum
#
# 1. NoRidge - $ 190,000
# 2. StoneBr - $ 170,000
# 3. Veenker - $ 162,500
# 4. Blmngtn - $ 159,895
# 5. NridgHt - $ 154,000
# 6. Somerst - $ 144,152
# 7. Gilbert - $ 141,000
# 8. Timber - $ 137,500
# 9. ClearCr - $ 130,000
# 10. NPkVill - $ 127,500
# 11. Blueste - $ 124,000
# 12. CollgCr - $ 110,000
# 13. Crawfor - $ 90,350
# 14. NAmes - $ 87,500
# 15. Mitchel - $ 84,500
# 16. BrDale - $ 83,000
# 17. NWAmes - $ 82,500
# 18. SawyerW - $ 76,000
# 19. MeadowV - $ 75,000
# 20. Sawyer - $ 62,383
# 21. SWISU - $ 60,000
# 22. Edwards - $ 58,500
# 23. BrkSide - $ 39,300
# 24. OldTown - $ 37,900
# 25. IDOTRR - $ 34,900
#
# Maximum
#
# 1. Edwards - $ 1,600,000
# 2. NoRidge - $ 755,000
# 3. NridgHt - $ 611,657
# 4. StoneBr - $ 556,581
# 5. OldTown - $ 475,000
# 6. CollgCr - $ 424,870
# 7. Somerst - $ 423,000
# 8. Crawfor - $ 392,500
# 9. Veenker - $ 385,000
# 10. Timber - $ 378,500
# 11. Gilbert - $ 377,500
# 12. NAmes - $ 345,000
# 13. ClearCr - $ 328,000
# 14. SawyerW - $ 320,000
# 15. NWAmes - $ 299,800
# 16. Mitchel - $ 271,000
# 17. Blmngtn - $ 264,561
# 18. BrkSide - $ 223,500
# 19. SWISU - $ 200,000
# 20. Sawyer - $ 190,000
# 21. IDOTRR - $ 169,500
# 22. NPkVill - $ 155,000
# 23. MeadowV - $ 151,400
# 24. Blueste - $ 151,000
# 25. BrDale - $ 125,000

# %%
# There is another outlier that I believe is also an inaccuracy. The neighborhood is the same as the 
# outlier I previously revealed. The neighborhood is relatively inexpensive. It's also in the Edwards 
# neighborhood, which stands out from others.
print(df[df['TotalSF'] > 7000])
print(df.iloc[523])
print(df.iloc[1298])
# Out:
#         Id  MSSubClass MSZoning Street Alley Neighborhood Condition1  \
# 523    524          60       RL   Pave  None      Edwards       PosN
# 1298  1299          60       RL   Pave  None      Edwards      Feedr
#
#      Condition2 HouseStyle  OverallQual  ... TotalBsmtSF  Heating GrLivArea  \
# 523        PosN     2Story           10  ...        3138     GasA      4676
# 1298       Norm     2Story           10  ...        6110     GasA      5642
#
#      KitchenQual  GarageType GarageFinish  GarageCars SalePrice TotalSF  \
# 523           Ex     BuiltIn          Fin           3    184750    7814
# 1298          Ex      Attchd          Fin           2   1600000   11752
#
#      HasPool
# 523    False
# 1298    True
#
# [2 rows x 24 columns]
# Id                  524
# MSSubClass           60
# MSZoning             RL
# Street             Pave
# Alley              None
# Neighborhood    Edwards
# Condition1         PosN
# Condition2         PosN
# HouseStyle       2Story
# OverallQual          10
# MasVnrType        Stone
# MasVnrArea        762.0
# ExterQual            Ex
# ExterCond            TA
# TotalBsmtSF        3138
# Heating            GasA
# GrLivArea          4676
# KitchenQual          Ex
# GarageType      BuiltIn
# GarageFinish        Fin
# GarageCars            3
# SalePrice        184750
# TotalSF            7814
# HasPool           False
# Name: 523, dtype: object
# Id                 1299
# MSSubClass           60
# MSZoning             RL
# Street             Pave
# Alley              None
# Neighborhood    Edwards
# Condition1        Feedr
# Condition2         Norm
# HouseStyle       2Story
# OverallQual          10
# MasVnrType        Stone
# MasVnrArea        796.0
# ExterQual            Ex
# ExterCond            TA
# TotalBsmtSF        6110
# Heating            GasA
# GrLivArea          5642
# KitchenQual          Ex
# GarageType       Attchd
# GarageFinish        Fin
# GarageCars            2
# SalePrice       1600000
# TotalSF           11752
# HasPool            True
# Name: 1298, dtype: object

# %%
# I want to compare these locations further with the data from the original df.
orig_df = pd.read_csv('../train.csv')
print(orig_df.iloc[[523,1298]].select_dtypes('int64'))
# Out:
#         Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  \
# 523    524          60    40094           10            5       2007
# 1298  1299          60    63887           10            5       2008
#
#       YearRemodAdd  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  WoodDeckSF  \
# 523           2008        2260           0        878  ...         208
# 1298          2008        5644           0        466  ...         214
#
#       OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  \
# 523           406              0          0            0         0        0
# 1298          292              0          0            0       480        0
#
#       MoSold  YrSold  SalePrice
# 523       10    2007     184750
# 1298       1    2008     160000
#
# [2 rows x 35 columns]

# %% [markdown]
# ### Figure 3 - Correlation of LotArea to SalePrice

# %%
model = sm.OLS(orig_df['SalePrice'], sm.add_constant(orig_df['LotArea']))
p = model.fit().params
# generate x-values for your regression line (two is sufficient)
x = orig_df['LotArea']
# scatter-plot data
ax = orig_df.plot(x='LotArea', y='SalePrice', kind='scatter', alpha = 0.1)
# plot regression line on the same axes, set x-axis limits
ax.plot(x, p.const + p['LotArea'] * x)
print ("correlation :",scipy.stats.pearsonr(orig_df['SalePrice'], orig_df['LotArea']))
# Out:
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# correlation : (0.2638433538714057, 1.1231391549193063e-24)

# %%
# These two homes are very large, on large plots of land, and brand new, so I believe that 
# the value is once again low by a factor of 10.
df.at[523,'SalePrice'] = 10 * df.iloc[523]['SalePrice']

# %%
# Looking back on the original df at the correlation of sale price and lot area, there is a decent
# correlation. Now we will examine all values with large LotArea's defined as greater than 40,000.
orig_df = pd.read_csv('../train.csv')
# --- Uncomment below to examine the resulting df for yourself.
# --- print(orig_df[orig_df['LotArea'] > 40000].select_dtypes('int64'))
print(df.iloc[[523,769,1298]].select_dtypes('int64'))
'{:,.0f}'.format(orig_df.LotArea.mean())
# Out:
#         Id  MSSubClass  OverallQual  TotalBsmtSF  GrLivArea  GarageCars  \
# 523    524          60           10         3138       4676           3
# 769    770          60            8         1650       3279           3
# 1298  1299          60           10         6110       5642           2
#
#       SalePrice  TotalSF
# 523     1847500     7814
# 769      538000     4929
# 1298    1600000    11752
# '10,517'

# %% [markdown]
# ### Figure 4 - Correlation of SalePrice and TotalSF among 3 outliers within LotArea

# %%
# An interesting find was a home with a much larger lot area, but only about a third of the price of our 
# other two extreme values.
model = sm.OLS(df.iloc[[523,769,1298]]['SalePrice'], sm.add_constant(df.iloc[[523,769,1298]]['TotalSF']))
p = model.fit().params
x = df.iloc[[523,769,1298]]['TotalSF']
ax = df.iloc[[523,769,1298]].plot(x='TotalSF', y='SalePrice', kind='scatter', alpha = 0.5)
ax.plot(x, p.const + p['TotalSF'] * x)
print ("correlation :",scipy.stats.pearsonr(df.iloc[[523,769,1298]]['SalePrice'], df.iloc[[523,769,1298]]['TotalSF']))
# Out:
# correlation : (0.7029210741162513, 0.5037573939582445)
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
# The above isn't technically a statistically significant result, however, it is largely 
# inline with our correlation of SalePrice to TotalSF overall. 
orig_df[orig_df['Neighborhood'] == 'Edwards'].groupby('SaleCondition').SalePrice.count()
# Out:
# SaleCondition
# Abnorml     8
# AdjLand     4
# Alloca      2
# Normal     82
# Partial     4
# Name: SalePrice, dtype: int64

# %% [markdown]
# ### Figure 5 - Correlation of SalePrice and TotalSF after outlier SalePrice
# #### updated values increased by a factor of 10

# %%
# These two changes
model = sm.OLS(df['SalePrice'], sm.add_constant(df['TotalSF']))
p = model.fit().params
# generate x-values for your regression line (two is sufficient)
x = df['TotalSF']
# scatter-plot data
ax = df.plot(x='TotalSF', y='SalePrice', kind='scatter', alpha = 0.1, c=r)
# plot regression line on the same axes, set x-axis limits
ax.plot(x, p.const + p['TotalSF'] * x)
print ("correlation :",scipy.stats.pearsonr(df['SalePrice'], df['TotalSF']))
# Out:
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# correlation : (0.8215488105837597, 0.0)

# %%
# The two outliers make more sense, in terms of the dataset now, thought they skew the data significantly.
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'Street', 'Alley', 'Neighborhood',
#        'Condition1', 'Condition2', 'HouseStyle', 'OverallQual', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'TotalBsmtSF', 'Heating',
#        'GrLivArea', 'KitchenQual', 'GarageType', 'GarageFinish', 'GarageCars',
#        'SalePrice', 'TotalSF', 'HasPool'],
#       dtype='object')

# %% [markdown]
# ### Examine all 3-dimensional correlations between all numeric columns and SalePrice and TotalSF

# %%
for col in df.select_dtypes('int64').drop(columns=['Id','TotalSF','SalePrice']).columns:    
    sns.set(style = "darkgrid")

    fig = plt.figure()
    ax = fig.add_subplot(111, projection = '3d')

    x = df[col]
    y = df['TotalSF']
    z = df['SalePrice']

    ax.set_xlabel(col)
    ax.set_ylabel("SF")
    ax.set_zlabel("Price")

    ax.scatter(x, y, z, c='g')

    plt.show()

# %%
# Another thing that stands out to me is the correlation of GarageCars and SF and Price, except for 4. So I
# am going to combine 4 into the column 3.
df['GarageCars'].replace(to_replace=4, value=3, inplace=True)
df['GarageCars'].unique()
# Out:
# array([2, 3, 1, 0])

# %% [markdown]
# ### Figure 6 - Correlation of GarageCars, TotalSF and SalePrice

# %%
sns.set(style = "darkgrid")

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')

x = df['GarageCars']
y = df['TotalSF']
z = df['SalePrice']

ax.set_xlabel('GarageCars')
ax.set_ylabel("SF")
ax.set_zlabel("Price")

ax.scatter(x, y, z, c='g')

plt.show()

# %% [markdown]
# ### Correlations of SalePrice and TotalSf by OverallQual

# %%
# One observation I've made is that each variable is pretty strongly correlated for lower values, 
# but I believe this will be explained in some of the qualitative variables.
for value in df.OverallQual.unique():
    col_model = sm.OLS(df[df['OverallQual'] == value]['SalePrice'], sm.add_constant(df[df['OverallQual'] == value]['TotalSF']))
    col_p = col_model.fit().params
    x = df[df['OverallQual'] == value]['TotalSF']
    ax = df[df['OverallQual'] == value].plot(x='TotalSF', y='SalePrice', kind='scatter', alpha = 0.5, title=value)
    corrcoef = scipy.stats.pearsonr(df[df['OverallQual'] == value]['SalePrice'], df[df['OverallQual'] == value]['TotalSF'])
    if(np.abs(corrcoef[0]) > .2):
        print(value, " correlation : ",corrcoef)
# Out:
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 7  correlation :  (0.718861814857261, 5.40313031836748e-52)
# 6  correlation :  (0.6909666311094307, 2.2375603137511756e-54)
# 8  correlation :  (0.7143956903286686, 1.5650935210041917e-27)
# 5  correlation :  (0.563663159577783, 1.1432288863414272e-34)
# 9  correlation :  (0.8043526145388762, 8.164069368827626e-11)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 4  correlation :  (0.6213515054855221, 9.905970022926983e-14)
# 10  correlation :  (0.8689793140593526, 2.8715070249070093e-06)
# 3  correlation :  (0.37330534506541835, 0.10497238735747137)
# 1  correlation :  (1.0, 1.0)
# 2  correlation :  (-0.21480864541642186, 0.8621744311325219)

# %%
# Overall Condition values over above three yeild strong correlations between SalePrice and TotalSF. 
print(df[(df['SalePrice'] > 35000) & (df['SalePrice'] < 61000) & (df['TotalSF'] > 700) & (df['TotalSF'] < 1000)])
# Out:
#         Id  MSSubClass MSZoning Street Alley Neighborhood Condition1  \
# 710    711          30       RL   Pave  None      BrkSide       Norm
# 916    917          20  C (all)   Pave  None       IDOTRR       Norm
# 1100  1101          30       RL   Pave  None        SWISU       Norm
#
#      Condition2 HouseStyle  OverallQual  ... TotalBsmtSF  Heating GrLivArea  \
# 710        Norm     1Story            3  ...         270     GasA       729
# 916        Norm     1Story            2  ...         480     GasA       480
# 1100       Norm     1Story            2  ...         290     GasA       438
#
#      KitchenQual  GarageType GarageFinish  GarageCars SalePrice TotalSF  \
# 710           TA        None         None           0     52000     999
# 916           TA      Detchd          Unf           1     35311     960
# 1100          Fa      Detchd          Unf           1     60000     728
#
#      HasPool
# 710    False
# 916    False
# 1100   False
#
# [3 rows x 24 columns]

# %% [markdown]
# ### Figure 7 - Correlation of TotalSF and SalePrice,
# #### restricted to SalePrice under $100,000 and TotalSF under 1400

# %%
# What I see above is that the first value, with id 711, Each of them seems to correlate roughly 
# between neighborhood mean values to sale price. IDOTRR is the cheapest average price of the 3, 
# and the home in that neighborhood is also the cheapest, and SWISU is the most expensive of the
# 3 on average, and the home in SWISU is the most expensive, despite being the smallest. I believe
# the appearance of these values as outliers is explained by the neighborhoods they are in, and 
# therefore they fit the dataset fairly well overall.
restricted_df = df[(df['SalePrice'] < 100000) & (df['TotalSF'] < 1400)]
model = sm.OLS(restricted_df['SalePrice'], sm.add_constant(restricted_df['TotalSF']))
p = model.fit().params
# generate x-values for your regression line (two is sufficient)
x = restricted_df['TotalSF']
# scatter-plot data
ax = restricted_df.plot(x='TotalSF', y='SalePrice', kind='scatter', alpha = 0.1)
# plot regression line on the same axes, set x-axis limits
ax.plot(x, p.const + p['TotalSF'] * x)
print ("correlation :",scipy.stats.pearsonr(restricted_df['SalePrice'], restricted_df['TotalSF']))
# Out:
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# correlation : (0.3613311656220852, 0.023817542914674514)

# %% [markdown]
# ##### As we see above, the restricted correlation is not strong, nor as statistically significant, as the
# ##### dataset as a whole.

# %% [markdown]
# ### Figure 8 - Correlation of TotalSF and SalePrice, restricted to those homes under $300,000

# %%
restricted_df = df[df['SalePrice'] < 300000]
model = sm.OLS(restricted_df['SalePrice'], sm.add_constant(restricted_df['TotalSF']))
p = model.fit().params
x = restricted_df['TotalSF']
ax = restricted_df.plot(x='TotalSF', y='SalePrice', kind='scatter', alpha = 0.1)
ax.plot(x, p.const + p['TotalSF'] * x)
print ("correlation :",scipy.stats.pearsonr(restricted_df['SalePrice'], restricted_df['TotalSF']))
# Out:
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# correlation : (0.7693090926839589, 3.282034835819395e-263)

# %% [markdown]
# ### Scatterplots to examine the correlation of TotalSF and SalePrice

# %%
# The correlation seems to be more quadratic than linear, which seems to suggest that neighborhood, as
# seen above, plays a role in both total sf and sale price, which I now hypothesize causes this affect.
# I will now loop over neighborhoods to view the correlation of area and sale price.
for value in sorted(df.Neighborhood.unique()):
    col_model = sm.OLS(df[df['Neighborhood'] == value]['SalePrice'], sm.add_constant(df[df['Neighborhood'] == value]['TotalSF']))
    col_p = col_model.fit().params
    x = df[df['Neighborhood'] == value]['TotalSF']
    ax = df[df['Neighborhood'] == value].plot(x='TotalSF', \
        y='SalePrice', kind='scatter', alpha = 0.5, \
        title= str(df[df['Neighborhood'] == value]['Id'].count()) \
        + ' - ' + value + ' - ${:,.2f}'.format(df[df['Neighborhood'] \
        == value]['SalePrice'].mean()))
    ax.plot(x, p.const + p['TotalSF'] * x)
    ax.plot(x, col_p.const + col_p['TotalSF'] * x)
    corrcoef = scipy.stats.pearsonr(df[df['Neighborhood'] == value]['SalePrice'], df[df['Neighborhood'] == value]['TotalSF'])
    if(np.abs(corrcoef[0]) > .2):
        print(value, " correlation : ",corrcoef)
# Out:
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# Blmngtn  correlation :  (0.6129754089287498, 0.008886716763331132)
# Blueste  correlation :  (1.0, 1.0)
# BrDale  correlation :  (0.6807692452276011, 0.0036974586923680976)
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# BrkSide  correlation :  (0.8638220838566508, 2.5898991828566336e-18)
# ClearCr  correlation :  (0.5524069807505488, 0.0023029114829260532)
# CollgCr  correlation :  (0.8893237924552659, 3.740611053320732e-52)
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# Crawfor  correlation :  (0.7334666121371041, 9.258704026777114e-10)
# Edwards  correlation :  (0.8844918359859018, 3.2349320319283905e-34)
# Gilbert  correlation :  (0.764510406809342, 2.4323091066126087e-16)
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# IDOTRR  correlation :  (0.6482105877446923, 1.4380953353038984e-05)
# MeadowV  correlation :  (0.8664834517621864, 6.838369602087765e-06)
# Mitchel  correlation :  (0.7035829046435447, 1.7155327101432072e-08)
# NAmes  correlation :  (0.7021845445384407, 9.577320071377748e-35)
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# NPkVill  correlation :  (0.5980573347140649, 0.08892555292997843)
# NWAmes  correlation :  (0.6915455414832496, 1.2561560246716434e-11)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# NoRidge  correlation :  (0.8963922170689058, 2.335189074696072e-15)
# NridgHt  correlation :  (0.8539935280001443, 5.590488329001563e-23)
# OldTown  correlation :  (0.6829829400041416, 7.890581164179535e-17)
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:345: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# SWISU  correlation :  (0.7583136237265367, 1.1231832945986113e-05)
# Sawyer  correlation :  (0.5423918764936194, 5.985817013981369e-07)
# SawyerW  correlation :  (0.9177475258372716, 1.5823696718461987e-24)
# Somerst  correlation :  (0.8423884033748057, 2.8553908199165774e-24)
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# StoneBr  correlation :  (0.9151638519374856, 1.4982867976915876e-10)
# Timber  correlation :  (0.8054439160830154, 1.0716766360356067e-09)
# Veenker  correlation :  (0.9369196402853521, 2.1244359686394447e-05)

# %% [markdown]
# ### Figure 9.1 - Correlation of YearBuilt and SalePrice on the original dataset

# %%
# I'd like to look more into my two major outliers in Edwards neighborhood, which I adjusted their
# values by a factor of 10. They were both newly built homes, of high quality, and very large size.
restricted_df = orig_df
model = sm.OLS(restricted_df['SalePrice'], sm.add_constant(restricted_df['YearBuilt']))
p = model.fit().params
x = restricted_df['YearBuilt']
ax = restricted_df.plot(x='YearBuilt', y='SalePrice', kind='scatter', alpha = 0.1)
ax.plot(x, p.const + p['YearBuilt'] * x)
print(p.const)
print ("correlation :",scipy.stats.pearsonr(restricted_df['SalePrice'], restricted_df['YearBuilt']))
# Out:
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# -2530308.245732358
# correlation : (0.5228973328794969, 2.9902290990158995e-103)

# %% [markdown]
# ### Figure 9.2 - Correlation of TotalSF and YearBuilt

# %%
df['YearBuilt'] = orig_df['YearBuilt']
restricted_df = df
model = sm.OLS(restricted_df['TotalSF'], sm.add_constant(restricted_df['YearBuilt']))
p = model.fit().params
x = restricted_df['YearBuilt']
ax = restricted_df.plot(x='YearBuilt', y='TotalSF', kind='scatter', alpha = 0.1)
ax.plot(x, p.const + p['YearBuilt'] * x)
print ("correlation :",scipy.stats.pearsonr(restricted_df['TotalSF'], restricted_df['YearBuilt']))
# Out:
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# correlation : (0.34713269256611656, 1.333148662766363e-42)

# %% [markdown]
# ### Figure 9.3 - Correlation of SalePrice and YearBuilt on updated dataset

# %%
model = sm.OLS(df['SalePrice'], sm.add_constant(df['YearBuilt']))
p = model.fit().params
x = df['YearBuilt']
ax = df.plot(x='YearBuilt', y='SalePrice', kind='scatter', alpha = 0.1)
ax.plot(x, p.const + p['YearBuilt'] * x, c='red')
print(p.const)
print ("correlation :",scipy.stats.pearsonr(df['SalePrice'], df['YearBuilt']))
# Out:
# /Users/skdod/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# -2694525.8141156556
# correlation : (0.4502098133812418, 8.955559672733592e-74)

# %% [markdown]
# ### Figure 9.4 - Quadratic regression of SalePrice and YearBuilt

# %%
model = np.poly1d(np.polyfit(df['YearBuilt'], df['SalePrice'], 2))

#add fitted polynomial line to scatterplot
polyline = np.linspace(1870, 2008, 50)
plt.scatter(df['YearBuilt'], df['SalePrice'], alpha=.04)
plt.plot(polyline, model(polyline))
plt.xlim(1860,2020)
plt.ylim(100000,300000)
plt.show()

# %% [markdown]
# ### Figure 9.5 - Quadratic regression of YearBuilt and TotalSF

# %%
model = np.poly1d(np.polyfit(df['YearBuilt'], df['TotalSF'], 2))

#add fitted polynomial line to scatterplot
polyline = np.linspace(1870, 2008, 50)
plt.scatter(df['YearBuilt'], df['TotalSF'], alpha=.04)
plt.plot(polyline, model(polyline))
plt.xlim(1860,2020)
plt.ylim(2000,3500)
plt.show()

# %% [markdown]
# ### Figure 9.6 - Quadratic regression of TotalSF And SalePrice

# %%
model = np.poly1d(np.polyfit(df['TotalSF'], df['SalePrice'], 2))

#add fitted polynomial line to scatterplot
polyline = np.linspace(200, 12000, 50)
plt.scatter(df['TotalSF'], df['SalePrice'], alpha=.5)
plt.plot(polyline, model(polyline), c='r')
plt.xlim(0,12100)
plt.ylim(2000,2000000)
plt.plot(x, .76 * x)
plt.show()

# %%
neighborhood_df = df.drop(columns=['Id','MSSubClass']).groupby('Neighborhood').mean()

scaled_neighborhood = scale(neighborhood_df.select_dtypes(['int64','float64']))
scaled_neighborhood_df = pd.DataFrame(scaled_neighborhood, columns=[neighborhood_df.select_dtypes(['int64','float64']).columns])
scaled_neighborhood_df_x = scaled_neighborhood_df
scaled_neighborhood_df_x.head()
# Out:
#   OverallQual MasVnrArea TotalBsmtSF GrLivArea GarageCars SalePrice   TotalSF  \
# 0    0.961016  -0.494713    0.998632 -0.324354   1.091933  0.149619  0.329472
# 1   -0.178874  -0.912913   -1.474674 -0.435877   0.410951 -0.738518 -0.976659
# 2   -0.481658   1.908490   -1.671644 -1.220391  -1.277317 -1.249475 -1.526990
# 3   -1.097665  -0.845061   -1.017040 -1.031962  -1.185835 -0.934594 -1.105966
# 4   -0.282686  -0.137103    0.645060  0.808984  -0.071411  0.423542  0.773094
#
#     HasPool YearBuilt
# 0 -0.454536  1.256703
# 1 -0.454536  0.275525
# 2 -0.454536 -0.057396
# 3 -0.454536 -1.612895
# 4 -0.454536 -0.246594

# %% [markdown]
# ### Figure 10.1

# %%
neighborhood_pca = PCA().fit(scaled_neighborhood_df)
plt.subplots(figsize=(10, 6))
plt.plot(neighborhood_pca.explained_variance_ratio_.cumsum())
plt.xlabel('Component #')
plt.ylabel('Cumulative ratio variance')
plt.title('Cumulative variance ratio explained by PCA components for state/resort summary statistics');
neighborhood_pca_x = neighborhood_pca.transform(scaled_neighborhood)
neighborhood_pca_x.shape
# Out:
# (25, 9)

# %% [markdown]
# ### Figure 10.2

# %%
x = neighborhood_pca_x[:, 0]
y = neighborhood_pca_x[:, 1]
neighborhood = df['Neighborhood'].unique()
pc_var = 100 * neighborhood_pca.explained_variance_ratio_.cumsum()[1]
plt.subplots(figsize=(10,8))
plt.scatter(x=x, y=y)
plt.xlabel('First component')
plt.ylabel('Second component')
plt.title(f'Neighborhoods summary PCA, {pc_var:.1f}% variance explained')
for s, x, y in zip(neighborhood, x, y):
    plt.annotate(s, (x, y))

# %%
print(df.groupby('Neighborhood').mean())
print(df[df['Neighborhood'] == 'Edwards'].mean())
print(orig_df[orig_df['Neighborhood'] == 'Edwards'].mean())
# Out:
#                       Id  MSSubClass  OverallQual  MasVnrArea  TotalBsmtSF  \
# Neighborhood
# Blmngtn       773.941176  114.117647     7.176471   45.588235  1324.411765
# Blueste       778.500000  160.000000     6.000000    0.000000   638.500000
# BrDale        719.187500  160.000000     5.687500  307.562500   583.875000
# BrkSide       734.724138   49.741379     5.051724    7.396552   765.413793
# ClearCr       604.928571   52.500000     5.892857   84.571429  1226.357143
# CollgCr       726.840000   43.300000     6.640000   97.226667  1157.586667
# Crawfor       801.078431   58.235294     6.274510   81.117647  1032.901961
# Edwards       762.930000   56.800000     5.080000   50.470000   899.820000
# Gilbert       749.151899   58.227848     6.556962   41.518987   869.025316
# IDOTRR        597.540541   53.648649     4.756757   16.216216   746.837838
# MeadowV       733.000000  163.529412     4.470588    4.705882   653.352941
# Mitchel       759.102041   56.632653     5.591837   61.306122  1094.734694
# NAmes         737.995556   38.777778     5.360000  101.142222  1026.168889
# NPkVill       781.444444  142.222222     6.000000    0.000000   933.111111
# NWAmes        822.452055   44.589041     6.328767  177.561644  1153.835616
# NoRidge       815.268293   53.658537     7.926829  420.024390  1493.756098
# NridgHt       609.714286   62.077922     8.259740  329.545455  1602.831169
# OldTown       694.194690   66.238938     5.389381   14.194690   810.230088
# SWISU         841.240000   72.200000     5.440000   10.080000   847.080000
# Sawyer        715.851351   40.608108     5.027027   41.040541   967.432432
# SawyerW       665.152542   58.220339     6.322034   70.898305  1027.525424
# Somerst       755.744186   74.186047     7.337209  150.325581  1133.046512
# StoneBr       669.520000   83.200000     8.160000  182.760000  1523.000000
# Timber        787.026316   39.473684     7.157895  159.947368  1354.526316
# Veenker       618.909091   61.818182     6.727273   32.727273  1321.272727
#
#                 GrLivArea  GarageCars      SalePrice      TotalSF   HasPool  \
# Neighborhood
# Blmngtn       1427.941176    2.352941  194870.882353  2752.352941  0.000000
# Blueste       1392.500000    2.000000  137500.000000  2031.000000  0.000000
# BrDale        1143.187500    1.125000  104493.750000  1727.062500  0.000000
# BrkSide       1203.068966    1.172414  124834.051724  1959.586207  0.000000
# ClearCr       1788.107143    1.750000  212565.428571  2997.357143  0.000000
# CollgCr       1480.500000    2.006667  197965.773333  2638.086667  0.000000
# Crawfor       1791.607843    1.627451  210624.725490  2816.980392  0.000000
# Edwards       1340.040000    1.180000  159247.200000  2239.860000  0.020000
# Gilbert       1641.316456    2.063291  192854.506329  2509.670886  0.000000
# IDOTRR        1142.297297    1.000000  100123.783784  1859.216216  0.000000
# MeadowV       1058.941176    0.882353   98576.470588  1712.294118  0.000000
# Mitchel       1294.204082    1.755102  156270.122449  2388.938776  0.020408
# NAmes         1310.311111    1.506667  145847.080000  2333.706667  0.004444
# NPkVill       1253.000000    2.000000  142694.444444  2186.111111  0.000000
# NWAmes        1727.780822    2.013699  189050.068493  2881.616438  0.027397
# NoRidge       2508.853659    2.634146  335295.317073  4002.609756  0.024390
# NridgHt       1915.948052    2.662338  316270.623377  3518.779221  0.000000
# OldTown       1479.725664    1.424779  128225.300885  2269.336283  0.000000
# SWISU         1801.240000    1.000000  142591.360000  2536.320000  0.000000
# Sawyer        1215.135135    1.459459  136793.135135  2182.567568  0.000000
# SawyerW       1595.016949    1.932203  186555.796610  2622.542373  0.000000
# Somerst       1596.651163    2.267442  225379.837209  2726.906977  0.000000
# StoneBr       1879.080000    2.400000  310499.000000  3402.080000  0.000000
# Timber        1749.368421    2.368421  242247.447368  3103.894737  0.000000
# Veenker       1539.636364    2.090909  238772.727273  2860.909091  0.000000
#
#                 YearBuilt
# Neighborhood
# Blmngtn       2005.235294
# Blueste       1980.000000
# BrDale        1971.437500
# BrkSide       1931.431034
# ClearCr       1966.571429
# CollgCr       1997.886667
# Crawfor       1941.549020
# Edwards       1955.970000
# Gilbert       1998.253165
# IDOTRR        1927.945946
# MeadowV       1972.588235
# Mitchel       1981.755102
# NAmes         1959.995556
# NPkVill       1976.444444
# NWAmes        1975.630137
# NoRidge       1995.439024
# NridgHt       2005.675325
# OldTown       1922.884956
# SWISU         1925.240000
# Sawyer        1963.675676
# SawyerW       1988.559322
# Somerst       2004.988372
# StoneBr       1998.480000
# Timber        1992.842105
# Veenker       1982.363636
# Id                762.93
# MSSubClass         56.80
# OverallQual         5.08
# MasVnrArea         50.47
# TotalBsmtSF       899.82
# GrLivArea        1340.04
# GarageCars          1.18
# SalePrice      159247.20
# TotalSF          2239.86
# HasPool             0.02
# YearBuilt        1955.97
# dtype: float64
# Id                  762.930000
# MSSubClass           56.800000
# LotFrontage          68.217391
# LotArea           10218.650000
# OverallQual           5.080000
# OverallCond           5.440000
# YearBuilt          1955.970000
# YearRemodAdd       1975.110000
# MasVnrArea           50.470000
# BsmtFinSF1          424.460000
# BsmtFinSF2           26.160000
# BsmtUnfSF           449.200000
# TotalBsmtSF         899.820000
# 1stFlrSF           1093.060000
# 2ndFlrSF            246.980000
# LowQualFinSF          0.000000
# GrLivArea          1340.040000
# BsmtFullBath          0.490000
# BsmtHalfBath          0.070000
# FullBath              1.360000
# HalfBath              0.190000
# BedroomAbvGr          2.880000
# KitchenAbvGr          1.050000
# TotRmsAbvGrd          6.120000
# Fireplaces            0.320000
# GarageYrBlt        1967.782051
# GarageCars            1.180000
# GarageArea          326.200000
# WoodDeckSF           70.770000
# OpenPorchSF          33.240000
# EnclosedPorch        26.380000
# 3SsnPorch             1.800000
# ScreenPorch          15.250000
# PoolArea             12.180000
# MiscVal              16.000000
# MoSold                5.750000
# YrSold             2007.940000
# SalePrice        128219.700000
# dtype: float64
# /var/folders/qp/hgh__lqs1dz1wk35m_9mqmn40000gn/T/ipykernel_3388/1965535549.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(df[df['Neighborhood'] == 'Edwards'].mean())
# /var/folders/qp/hgh__lqs1dz1wk35m_9mqmn40000gn/T/ipykernel_3388/1965535549.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(orig_df[orig_df['Neighborhood'] == 'Edwards'].mean())

# %%
# I notice that Edwards neighborhood is again an outlier, and I want to understand why. I will examine this
# further by replacing the updated values with the original values, and then running the above on the 
# original sale price column.

neighborhood_df = df.drop(columns=['Id','MSSubClass'])
neighborhood_df['SalePrice'] = orig_df['SalePrice']
neighborhood_df = neighborhood_df.groupby('Neighborhood').mean()
print(neighborhood_df.iloc[7])
scaled_neighborhood = scale(neighborhood_df.select_dtypes(['int64','float64']))
scaled_neighborhood_df = pd.DataFrame(scaled_neighborhood, columns=[neighborhood_df.select_dtypes(['int64','float64']).columns])
scaled_neighborhood_df_x = scaled_neighborhood_df
scaled_neighborhood_df_x.head()
# Out:
# OverallQual         5.08
# MasVnrArea         50.47
# TotalBsmtSF       899.82
# GrLivArea        1340.04
# GarageCars          1.18
# SalePrice      128219.70
# TotalSF          2239.86
# HasPool             0.02
# YearBuilt        1955.97
# Name: Edwards, dtype: float64
#   OverallQual MasVnrArea TotalBsmtSF GrLivArea GarageCars SalePrice   TotalSF  \
# 0    0.961016  -0.494713    0.998632 -0.324354   1.091933  0.166817  0.329472
# 1   -0.178874  -0.912913   -1.474674 -0.435877   0.410951 -0.710721 -0.976659
# 2   -0.481658   1.908490   -1.671644 -1.220391  -1.277317 -1.215581 -1.526990
# 3   -1.097665  -0.845061   -1.017040 -1.031962  -1.185835 -0.904458 -1.105966
# 4   -0.282686  -0.137103    0.645060  0.808984  -0.071411  0.437471  0.773094
#
#     HasPool YearBuilt
# 0 -0.454536  1.256703
# 1 -0.454536  0.275525
# 2 -0.454536 -0.057396
# 3 -0.454536 -1.612895
# 4 -0.454536 -0.246594

# %%
neighborhood_pca = PCA().fit(scaled_neighborhood_df)
plt.subplots(figsize=(10, 6))
plt.plot(neighborhood_pca.explained_variance_ratio_.cumsum())
plt.xlabel('Component #')
plt.ylabel('Cumulative ratio variance')
plt.title('Cumulative variance ratio explained by PCA components for state/resort summary statistics');
neighborhood_pca_x = neighborhood_pca.transform(scaled_neighborhood)
neighborhood_pca_x.shape
# Out:
# (25, 9)

# %%
x = neighborhood_pca_x[:, 0]
y = neighborhood_pca_x[:, 1]
neighborhood = df['Neighborhood'].unique()
pc_var = 100 * neighborhood_pca.explained_variance_ratio_.cumsum()[1]
plt.subplots(figsize=(10,8))
plt.scatter(x=x, y=y)
plt.xlabel('First component')
plt.ylabel('Second component')
plt.title(f'Neighborhoods summary PCA, {pc_var:.1f}% variance explained')
for s, x, y in zip(neighborhood, x, y):
    plt.annotate(s, (x, y))

# %%
df['MSSubClass'] = df['MSSubClass'].astype(str)
sub_class_df = df.drop(columns=['Id']).groupby('MSSubClass').mean()

scaled_sub_class = scale(sub_class_df.select_dtypes(['int64','float64']))
scaled_sub_class_df = pd.DataFrame(scaled_sub_class, columns=[sub_class_df.select_dtypes(['int64','float64']).columns])
scaled_sub_class_df_x = scaled_sub_class_df
scaled_sub_class_df_x.head()
# Out:
#   OverallQual MasVnrArea TotalBsmtSF GrLivArea GarageCars SalePrice   TotalSF  \
# 0    1.699161   0.787949    2.108390 -0.231424   1.409555  1.154773  0.670378
# 1    0.517206   1.701692   -1.195150 -0.117097   0.328508 -0.403500 -0.529752
# 2   -1.476625  -0.624772   -1.763564 -1.523697  -1.659878 -1.315099 -1.965517
# 3   -1.002782  -0.761860   -0.364218  0.416377  -0.938390 -0.630076  0.212929
# 4    0.375990   0.650409    1.920693 -0.163570   0.836725  0.764669  0.655952
#
#     HasPool YearBuilt
# 0 -0.423384  1.468436
# 1 -0.423384  1.055022
# 2 -0.423384  0.841308
# 3 -0.423384 -1.023607
# 4 -0.314565  0.727259

# %%
sub_class_pca = PCA().fit(scaled_sub_class_df)
plt.subplots(figsize=(10, 6))
plt.plot(sub_class_pca.explained_variance_ratio_.cumsum())
plt.xlabel('Component #')
plt.ylabel('Cumulative ratio variance')
plt.title('Cumulative variance ratio explained by PCA components for state/resort summary statistics');
sub_class_pca_x = sub_class_pca.transform(scaled_sub_class)
sub_class_pca_x.shape
# Out:
# (15, 9)

# %%
x = sub_class_pca_x[:, 0]
y = sub_class_pca_x[:, 1]
sub_class = df['MSSubClass'].unique()
pc_var = 100 * sub_class_pca.explained_variance_ratio_.cumsum()[1]
plt.subplots(figsize=(10,8))
plt.scatter(x=x, y=y)
plt.xlabel('First component')
plt.ylabel('Second component')
plt.title(f'Neighborhoods summary PCA, {pc_var:.1f}% variance explained')
for s, x, y in zip(sub_class, x, y):
    plt.annotate(s, (x, y))

# %%
# We see above that 160, which is newer 2-story homes and split foyer homes, 85, are possibly outliers.
# An obvious connection here is to area, which will be greater for 2-story homes.

# %%
corr = df.select_dtypes(['int64','float64']).drop(columns=['Id']).corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_76b5d_row0_col0, #T_76b5d_row1_col1, #T_76b5d_row2_col2, #T_76b5d_row3_col3, #T_76b5d_row4_col4, #T_76b5d_row5_col5, #T_76b5d_row6_col6, #T_76b5d_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_76b5d_row0_col1, #T_76b5d_row1_col7 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_76b5d_row0_col2, #T_76b5d_row7_col0 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_76b5d_row0_col3, #T_76b5d_row0_col6 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_76b5d_row0_col4 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_76b5d_row0_col5 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_76b5d_row0_col7 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_76b5d_row1_col0, #T_76b5d_row1_col2, #T_76b5d_row1_col4, #T_76b5d_row3_col7, #T_76b5d_row7_col1, #T_76b5d_row7_col3, #T_76b5d_row7_col5, #T_76b5d_row7_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_76b5d_row1_col3 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_76b5d_row1_col5 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_76b5d_row1_col6 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_76b5d_row2_col0, #T_76b5d_row5_col1 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_76b5d_row2_col1 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_76b5d_row2_col3 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_76b5d_row2_col4 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_76b5d_row2_col5 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_76b5d_row2_col6 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_76b5d_row2_col7 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_76b5d_row3_col0, #T_76b5d_row5_col7 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_76b5d_row3_col1 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_76b5d_row3_col2 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_76b5d_row3_col4 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_76b5d_row3_col5, #T_76b5d_row5_col0 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_76b5d_row3_col6 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_76b5d_row4_col0 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_76b5d_row4_col1 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_76b5d_row4_col2 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_76b5d_row4_col3 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_76b5d_row4_col5 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_76b5d_row4_col6 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_76b5d_row4_col7 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_76b5d_row5_col2 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_76b5d_row5_col3 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_76b5d_row5_col4, #T_76b5d_row7_col4 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_76b5d_row5_col6, #T_76b5d_row6_col2 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_76b5d_row6_col0 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_76b5d_row6_col1 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_76b5d_row6_col3 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_76b5d_row6_col4 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_76b5d_row6_col5 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_76b5d_row6_col7 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_76b5d_row7_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_76b5d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >OverallQual</th>
#       <th class="col_heading level0 col1" >MasVnrArea</th>
#       <th class="col_heading level0 col2" >TotalBsmtSF</th>
#       <th class="col_heading level0 col3" >GrLivArea</th>
#       <th class="col_heading level0 col4" >GarageCars</th>
#       <th class="col_heading level0 col5" >SalePrice</th>
#       <th class="col_heading level0 col6" >TotalSF</th>
#       <th class="col_heading level0 col7" >YearBuilt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76b5d_level0_row0" class="row_heading level0 row0" >OverallQual</th>
#       <td id="T_76b5d_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_76b5d_row0_col1" class="data row0 col1" >0.407252</td>
#       <td id="T_76b5d_row0_col2" class="data row0 col2" >0.537808</td>
#       <td id="T_76b5d_row0_col3" class="data row0 col3" >0.593007</td>
#       <td id="T_76b5d_row0_col4" class="data row0 col4" >0.609512</td>
#       <td id="T_76b5d_row0_col5" class="data row0 col5" >0.702909</td>
#       <td id="T_76b5d_row0_col6" class="data row0 col6" >0.668155</td>
#       <td id="T_76b5d_row0_col7" class="data row0 col7" >0.572323</td>
#     </tr>
#     <tr>
#       <th id="T_76b5d_level0_row1" class="row_heading level0 row1" >MasVnrArea</th>
#       <td id="T_76b5d_row1_col0" class="data row1 col0" >0.407252</td>
#       <td id="T_76b5d_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_76b5d_row1_col2" class="data row1 col2" >0.360067</td>
#       <td id="T_76b5d_row1_col3" class="data row1 col3" >0.388052</td>
#       <td id="T_76b5d_row1_col4" class="data row1 col4" >0.364827</td>
#       <td id="T_76b5d_row1_col5" class="data row1 col5" >0.464459</td>
#       <td id="T_76b5d_row1_col6" class="data row1 col6" >0.444454</td>
#       <td id="T_76b5d_row1_col7" class="data row1 col7" >0.311600</td>
#     </tr>
#     <tr>
#       <th id="T_76b5d_level0_row2" class="row_heading level0 row2" >TotalBsmtSF</th>
#       <td id="T_76b5d_row2_col0" class="data row2 col0" >0.537808</td>
#       <td id="T_76b5d_row2_col1" class="data row2 col1" >0.360067</td>
#       <td id="T_76b5d_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_76b5d_row2_col3" class="data row2 col3" >0.454868</td>
#       <td id="T_76b5d_row2_col4" class="data row2 col4" >0.437908</td>
#       <td id="T_76b5d_row2_col5" class="data row2 col5" >0.669013</td>
#       <td id="T_76b5d_row2_col6" class="data row2 col6" >0.826742</td>
#       <td id="T_76b5d_row2_col7" class="data row2 col7" >0.391452</td>
#     </tr>
#     <tr>
#       <th id="T_76b5d_level0_row3" class="row_heading level0 row3" >GrLivArea</th>
#       <td id="T_76b5d_row3_col0" class="data row3 col0" >0.593007</td>
#       <td id="T_76b5d_row3_col1" class="data row3 col1" >0.388052</td>
#       <td id="T_76b5d_row3_col2" class="data row3 col2" >0.454868</td>
#       <td id="T_76b5d_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_76b5d_row3_col4" class="data row3 col4" >0.469594</td>
#       <td id="T_76b5d_row3_col5" class="data row3 col5" >0.723989</td>
#       <td id="T_76b5d_row3_col6" class="data row3 col6" >0.874373</td>
#       <td id="T_76b5d_row3_col7" class="data row3 col7" >0.199010</td>
#     </tr>
#     <tr>
#       <th id="T_76b5d_level0_row4" class="row_heading level0 row4" >GarageCars</th>
#       <td id="T_76b5d_row4_col0" class="data row4 col0" >0.609512</td>
#       <td id="T_76b5d_row4_col1" class="data row4 col1" >0.364827</td>
#       <td id="T_76b5d_row4_col2" class="data row4 col2" >0.437908</td>
#       <td id="T_76b5d_row4_col3" class="data row4 col3" >0.469594</td>
#       <td id="T_76b5d_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_76b5d_row4_col5" class="data row4 col5" >0.547258</td>
#       <td id="T_76b5d_row4_col6" class="data row4 col6" >0.539715</td>
#       <td id="T_76b5d_row4_col7" class="data row4 col7" >0.546073</td>
#     </tr>
#     <tr>
#       <th id="T_76b5d_level0_row5" class="row_heading level0 row5" >SalePrice</th>
#       <td id="T_76b5d_row5_col0" class="data row5 col0" >0.702909</td>
#       <td id="T_76b5d_row5_col1" class="data row5 col1" >0.464459</td>
#       <td id="T_76b5d_row5_col2" class="data row5 col2" >0.669013</td>
#       <td id="T_76b5d_row5_col3" class="data row5 col3" >0.723989</td>
#       <td id="T_76b5d_row5_col4" class="data row5 col4" >0.547258</td>
#       <td id="T_76b5d_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_76b5d_row5_col6" class="data row5 col6" >0.821549</td>
#       <td id="T_76b5d_row5_col7" class="data row5 col7" >0

# %%
# I'm going to drop MasVnrArea as well now. Unlike year built, this isn't the 
# type of value that would be parabolic.
df.drop(columns=['MasVnrArea'], inplace = True)

# %%
corr = df.select_dtypes(['int64','float64']).drop(columns=['Id']).corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_6ef9b_row0_col0, #T_6ef9b_row1_col1, #T_6ef9b_row2_col2, #T_6ef9b_row3_col3, #T_6ef9b_row4_col4, #T_6ef9b_row5_col5, #T_6ef9b_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6ef9b_row0_col1, #T_6ef9b_row1_col6 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_6ef9b_row0_col2, #T_6ef9b_row0_col5 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_6ef9b_row0_col3 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_6ef9b_row0_col4 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_6ef9b_row0_col6 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_6ef9b_row1_col0, #T_6ef9b_row1_col3, #T_6ef9b_row2_col6, #T_6ef9b_row6_col1, #T_6ef9b_row6_col2, #T_6ef9b_row6_col4, #T_6ef9b_row6_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_6ef9b_row1_col2 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_6ef9b_row1_col4 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_6ef9b_row1_col5 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_6ef9b_row2_col0 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_6ef9b_row2_col1 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_6ef9b_row2_col3 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_6ef9b_row2_col4 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_6ef9b_row2_col5 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_6ef9b_row3_col0 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_6ef9b_row3_col1, #T_6ef9b_row6_col0 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_6ef9b_row3_col2 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_6ef9b_row3_col4 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_6ef9b_row3_col5 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_6ef9b_row3_col6 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_6ef9b_row4_col0 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_6ef9b_row4_col1 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_6ef9b_row4_col2 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_6ef9b_row4_col3, #T_6ef9b_row6_col3 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_6ef9b_row4_col5 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_6ef9b_row4_col6 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_6ef9b_row5_col0 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_6ef9b_row5_col1 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_6ef9b_row5_col2 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_6ef9b_row5_col3 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_6ef9b_row5_col4 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_6ef9b_row5_col6 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6ef9b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >OverallQual</th>
#       <th class="col_heading level0 col1" >TotalBsmtSF</th>
#       <th class="col_heading level0 col2" >GrLivArea</th>
#       <th class="col_heading level0 col3" >GarageCars</th>
#       <th class="col_heading level0 col4" >SalePrice</th>
#       <th class="col_heading level0 col5" >TotalSF</th>
#       <th class="col_heading level0 col6" >YearBuilt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ef9b_level0_row0" class="row_heading level0 row0" >OverallQual</th>
#       <td id="T_6ef9b_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_6ef9b_row0_col1" class="data row0 col1" >0.537808</td>
#       <td id="T_6ef9b_row0_col2" class="data row0 col2" >0.593007</td>
#       <td id="T_6ef9b_row0_col3" class="data row0 col3" >0.609512</td>
#       <td id="T_6ef9b_row0_col4" class="data row0 col4" >0.702909</td>
#       <td id="T_6ef9b_row0_col5" class="data row0 col5" >0.668155</td>
#       <td id="T_6ef9b_row0_col6" class="data row0 col6" >0.572323</td>
#     </tr>
#     <tr>
#       <th id="T_6ef9b_level0_row1" class="row_heading level0 row1" >TotalBsmtSF</th>
#       <td id="T_6ef9b_row1_col0" class="data row1 col0" >0.537808</td>
#       <td id="T_6ef9b_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_6ef9b_row1_col2" class="data row1 col2" >0.454868</td>
#       <td id="T_6ef9b_row1_col3" class="data row1 col3" >0.437908</td>
#       <td id="T_6ef9b_row1_col4" class="data row1 col4" >0.669013</td>
#       <td id="T_6ef9b_row1_col5" class="data row1 col5" >0.826742</td>
#       <td id="T_6ef9b_row1_col6" class="data row1 col6" >0.391452</td>
#     </tr>
#     <tr>
#       <th id="T_6ef9b_level0_row2" class="row_heading level0 row2" >GrLivArea</th>
#       <td id="T_6ef9b_row2_col0" class="data row2 col0" >0.593007</td>
#       <td id="T_6ef9b_row2_col1" class="data row2 col1" >0.454868</td>
#       <td id="T_6ef9b_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_6ef9b_row2_col3" class="data row2 col3" >0.469594</td>
#       <td id="T_6ef9b_row2_col4" class="data row2 col4" >0.723989</td>
#       <td id="T_6ef9b_row2_col5" class="data row2 col5" >0.874373</td>
#       <td id="T_6ef9b_row2_col6" class="data row2 col6" >0.199010</td>
#     </tr>
#     <tr>
#       <th id="T_6ef9b_level0_row3" class="row_heading level0 row3" >GarageCars</th>
#       <td id="T_6ef9b_row3_col0" class="data row3 col0" >0.609512</td>
#       <td id="T_6ef9b_row3_col1" class="data row3 col1" >0.437908</td>
#       <td id="T_6ef9b_row3_col2" class="data row3 col2" >0.469594</td>
#       <td id="T_6ef9b_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_6ef9b_row3_col4" class="data row3 col4" >0.547258</td>
#       <td id="T_6ef9b_row3_col5" class="data row3 col5" >0.539715</td>
#       <td id="T_6ef9b_row3_col6" class="data row3 col6" >0.546073</td>
#     </tr>
#     <tr>
#       <th id="T_6ef9b_level0_row4" class="row_heading level0 row4" >SalePrice</th>
#       <td id="T_6ef9b_row4_col0" class="data row4 col0" >0.702909</td>
#       <td id="T_6ef9b_row4_col1" class="data row4 col1" >0.669013</td>
#       <td id="T_6ef9b_row4_col2" class="data row4 col2" >0.723989</td>
#       <td id="T_6ef9b_row4_col3" class="data row4 col3" >0.547258</td>
#       <td id="T_6ef9b_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_6ef9b_row4_col5" class="data row4 col5" >0.821549</td>
#       <td id="T_6ef9b_row4_col6" class="data row4 col6" >0.450210</td>
#     </tr>
#     <tr>
#       <th id="T_6ef9b_level0_row5" class="row_heading level0 row5" >TotalSF</th>
#       <td id="T_6ef9b_row5_col0" class="data row5 col0" >0.668155</td>
#       <td id="T_6ef9b_row5_col1" class="data row5 col1" >0.826742</td>
#       <td id="T_6ef9b_row5_col2" class="data row5 col2" >0.874373</td>
#       <td id="T_6ef9b_row5_col3" class="data row5 col3" >0.539715</td>
#       <td id="T_6ef9b_row5_col4" class="data row5 col4" >0.821549</td>
#       <td id="T_6ef9b_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_6ef9b_row5_col6" class="data row5 col6" >0.347133</td>
#     </tr>
#     <tr>
#       <th id="T_6ef9b_level0_row6" class="row_heading level0 row6" >YearBuilt</th>
#       <td id="T_6ef9b_row6_col0" class="data row6 col0" >0.572323</td>
#       <td id="T_6ef9b_row6_col1" class="data row6 col1" >0.391452</td>
#       <td id="T_6ef9b_row6_col2" class="data row6 col2" >0.199010</td>
#       <td id="T_6ef9b_row6_col3" class="data row6 col3" >0.546073</td>
#       <td id="T_6ef9b_row6_col4" class="data row6 col4" >0.450210</td>
#       <td id="T_6ef9b_row6_col5" class="data row6 col5" >0.347133</td>
#       <td id="T_6ef9b_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
datapath = '../data'
save_file(df, 'house_refined_data_cleaned.csv', datapath)
# Out:
# A file already exists with this name.
#
# Do you want to overwrite? (Y/N)Y
# Writing file.  "../data/house_refined_data_cleaned.csv"
